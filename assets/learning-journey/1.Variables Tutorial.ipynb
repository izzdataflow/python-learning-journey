# %% [markdown]
# ## Variables in Python

# %%
x = 22
print(x)
type(x)
# Out:
# 22
# int

# %%
y = 'Mint Chocolate Chip'
Y = 'Chocolate'
print(y)
type(y)
# Out:
# Mint Chocolate Chip
# str

# %%
x,y,z = 'Chocolate', 'Vanilla', 'Rocky Road'
print(x)
print(y)
print(z)
# Out:
# Chocolate
# Vanilla
# Rocky Road

# %%
x = y = z = 'Root Beer Float'
print(x)
print(y)
print(z)
# Out:
# Root Beer Float
# Root Beer Float
# Root Beer Float

# %%
#list
ice_cream = ['Chocolate', 'Vanilla', 'Rocky Road']
x,y,z = ice_cream
print(x)
print(y)
print(z)
# Out:
# Chocolate
# Vanilla
# Rocky Road

# %%
#Snake Case
test_variable = 'Vanilla Swirl'

# %%
#doable
testvar = 'Vanilla Swirl'
test_var = 'Vanilla Swirl'
_test_var = 'Vanilla Swirl'
testVar = 'Vanilla Swirl'
TestVar = 'Vanilla Swirl'
testVar2 = 'Vanilla Swirl'

# %%
#not-doable
2testVar = 'Vanilla Swirl'
test-Var2 = 'Vanilla Swirl'
test Var2 = 'Vanilla Swirl'
test Var2 = 'Vanilla Swirl'

# %%
#not-doable (different data type)
x = 'Ice Cream is my favorite' + 2
print(x)

#doable (use comma instead of + for different data type)
x = 'Ice Cream'
y = 2
print(x,y)
